# %%
# %matplotlib inline
import numpy as np
from sklearn import preprocessing, neighbors
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('features.csv')
PA = pd.read_csv('features_train_PA.csv')
ER = pd.read_csv('features_train.csv')
CL = pd.read_csv('features_train_CL.csv')
CFG = pd.read_csv('features_train_CFG.csv')


frames = [ER,PA,CL,CFG]

# %%
PA
# Out:
#      Unnamed: 0 Name  Vertex  Edges   Density  Max. Degree  Avg. Degree  \
# 0             0   PA      10      9  0.200000            4     1.800000
# 1             1   PA      10     24  0.533333            9     4.800000
# 2             2   PA      20     19  0.100000            6     1.900000
# 3             3   PA      20     84  0.442105           15     8.400000
# 4             4   PA      20     99  0.521053           18     9.900000
# ..          ...  ...     ...    ...       ...          ...          ...
# 595         595   PA     240   5184  0.180753          239    43.200000
# 596         596   PA     240   4199  0.146409          239    34.991667
# 597         597   PA     240   3164  0.110321          239    26.366667
# 598         598   PA     240   2079  0.072490          239    17.325000
# 599         599   PA     240    944  0.032915          239     7.866667
#
#      Max. k-core  Avg. Clustering Coeff.  Diameter  Average Path Length  \
# ...

# %%
ER
# Out:
#      Unnamed: 0 Name  Vertex  Edges   Density  Max. Degree  Avg. Degree  \
# 0             0   ER      20     50  0.263158            8     5.000000
# 1             1   ER      20     80  0.421053           10     8.000000
# 2             2   ER      20     83  0.436842           10     8.300000
# 3             3   ER      20    113  0.594737           15    11.300000
# 4             4   ER      20    131  0.689474           16    13.100000
# ..          ...  ...     ...    ...       ...          ...          ...
# 199         199   ER     240  14431  0.503173          145   120.258333
# 200         200   ER     240  17291  0.602894          167   144.091667
# 201         201   ER     240  20105  0.701011          185   167.541667
# 202         202   ER     240  22827  0.795921          207   190.225000
# 203         203   ER     240  25818  0.900209          226   215.150000
#
#      Max. k-core  Avg. Clustering Coeff.  Diameter  Average Path Length  \
# ...

# %%
CL
# Out:
#     Unnamed: 0 Name  Vertex  Edges   Density  Max. Degree  Avg. Degree  \
# 0            0   CL      40     94  0.120513           11     4.700000
# 1            1   CL      50    113  0.092245            9     4.520000
# 2            2   CL      60    170  0.096045           10     5.666667
# 3            3   CL      70    232  0.096066           14     6.628571
# 4            4   CL      80    309  0.097785           15     7.725000
# 5            5   CL      90    416  0.103870           19     9.244444
# 6            6   CL     100    508  0.102626           19    10.160000
# 7            7   CL     110    589  0.098249           19    10.709091
# 8            8   CL     120    735  0.102941           21    12.250000
# 9            9   CL     130    890  0.106142           24    13.692308
# 10          10   CL     140    990  0.101747           23    14.142857
# 11          11   CL     150   1095  0.097987           25    14.600000
# ...

# %%
CFG
# Out:
#     Unnamed: 0 Name  Vertex  Edges   Density  Max. Degree  Avg. Degree  \
# 0            0  CFG      11     10  0.181818            6     1.818182
# 1            1  CFG      24     23  0.083333            4     1.916667
# 2            2  CFG      11     10  0.181818            3     1.818182
# 3            3  CFG      13     12  0.153846            4     1.846154
# 4            4  CFG      23     22  0.086957            4     1.913043
# 5            5  CFG      14     13  0.142857            4     1.857143
# 6            6  CFG      11     10  0.181818            4     1.818182
# 7            7  CFG      13     12  0.153846            6     1.846154
# 8            8  CFG      12     11  0.166667            4     1.833333
# 9            9  CFG      13     12  0.153846            4     1.846154
# 10          10  CFG      20     19  0.100000            4     1.900000
# 11          11  CFG      10      9  0.200000            3     1.800000
# ...

# %%
result = pd.concat(frames)

# %%
df_label= result["Name"]

# %%
df_feature = result[['Vertex', 'Edges', 'Density', 'Max. Degree', 'Avg. Degree',
       'Max. k-core', 'Avg. Clustering Coeff.', 'Diameter',
       'Average Path Length', 'Total Triangles',
       'Avg. Eigenvector Centrality']]

# %%
df_feature
# Out:
#     Vertex  Edges   Density  Max. Degree  Avg. Degree  Max. k-core  \
# 0       20     50  0.263158            8     5.000000            4
# 1       20     80  0.421053           10     8.000000            7
# 2       20     83  0.436842           10     8.300000            6
# 3       20    113  0.594737           15    11.300000            9
# 4       20    131  0.689474           16    13.100000           11
# ..     ...    ...       ...          ...          ...          ...
# 10      20     19  0.100000            4     1.900000            1
# 11      10      9  0.200000            3     1.800000            1
# 12      12     11  0.166667            3     1.833333            1
# 13      15     14  0.133333            4     1.866667            1
# 14      11     10  0.181818            3     1.818182            1
#
#     Avg. Clustering Coeff.  Diameter  Average Path Length  Total Triangles  \
# 0                 0.223214         4             1.984211             20.0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_feature,df_label,test_size=0.2)

# %%
clf_kn = neighbors.KNeighborsClassifier(n_neighbors=20)

# %%
clf_kn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
score = clf_kn.score(X_test, y_test)

# %%
score
# Out:
# 0.7678571428571429

# %%
test_Graph = df[['Vertex', 'Edges', 'Density', 'Max. Degree', 'Avg. Degree',
       'Max. k-core', 'Avg. Clustering Coeff.', 'Diameter',
       'Average Path Length', 'Total Triangles',
       'Avg. Eigenvector Centrality']]
test_Graph
# Out:
#    Vertex  Edges   Density  Max. Degree  Avg. Degree  Max. k-core  \
# 0      49     92  0.078231            6     3.755102            3
# 1      49     93  0.079082            7     3.795918            3
# 2     213  16089  0.712596          205   151.070423          111
# 3      91    582  0.142125           87    12.791209           11
# 4      62    159  0.084082           12     5.129032            4
# 5      33     91  0.172348           16     5.515152            5
# 6     453   2025  0.019780          237     8.940397           10
#
#    Avg. Clustering Coeff.  Diameter  Average Path Length  Total Triangles  \
# 0                0.275510        17             6.160714             23.0
# 1                0.137804        16             5.806122             17.0
# 2                0.758262         2             1.287404         622414.0
# 3                0.860053         3             1.868132           1902.0
# ...

# %%
clf_kn.predict(test_Graph)
# Out:
# array(['PA', 'PA', 'ER', 'PA', 'ER', 'ER', 'PA'], dtype=object)

# %%
df
# Out:
#    Unnamed: 0                       Name  Vertex  Edges   Density  \
# 0           0                  G_Enz_540      49     92  0.078231
# 1           1                 G_Enz_g300      49     93  0.079082
# 2           2           bn_mouse_brain_1     213  16089  0.712596
# 3           3  bn_macaque_rhesus_brain_2      91    582  0.142125
# 4           4               soc_dolphins      62    159  0.084082
# 5           5           soc_firm_hi_tech      33     91  0.172348
#
#    Max. Degree  Avg. Degree  Max. k-core  Avg. Clustering Coeff.  Diameter  \
# 0            6     3.755102            3                0.275510        17
# 1            7     3.795918            3                0.137804        16
# 2          205   151.070423          111                0.758262         2
# 3           87    12.791209           11                0.860053         3
# 4           12     5.129032            4                0.258958         8
# ...
